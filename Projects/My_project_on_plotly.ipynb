# %% [markdown]
# ## My Project On Plotly

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio

# %%
df = pd.read_csv("C:\\Users\\DELL\\OneDrive\\Desktop\\Bhargav's visual python\superstore_data.csv")
df
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %% [markdown]
# # MY 1ST GRAPH
# Here, I will present what are the marital statuses of people on the basis of birth year

# %%
figure1 = px.scatter(df,x='Year_Birth',y='Marital_Status',title="Year_Birth vs Marital_Status")
figure1.show()

# %% [markdown]
# ## MY 2nd Graph
# Here, I will present in which year most people are still single.

# %%
df2 = df[df["Marital_Status"] == "Single"]
df2.groupby("Year_Birth")
figure2 = px.bar(df2,x=df2["Year_Birth"].drop_duplicates(),y=df2["Year_Birth"].value_counts(),labels={"x":"Birth Year","y":"Count of People born in that year"},title="Year_Birth vs Marital_status")
figure2.show()

# %% [markdown]
# # MY 3rd Graph
# Here,I will present count of people by birth year who done phd in education are divorced and have income more than 50k.

# %%
df3 = df[df["Marital_Status"]=="Divorced"][df["Education"]=="PhD"][df["Income"]>50000]
print(df3)

figure3 = px.bar(df3,x=df["Year_Birth"].drop_duplicates(),y=df["Year_Birth"].value_counts(),labels={"x":"Birth year","y":"Count of people born in that year"},title="DIVORCED PhD People by Birth year")
figure3.show()
# Out:
#          Id  Year_Birth Education Marital_Status   Income  Kidhome  Teenhome  \
# 30     8890        1971       PhD       Divorced  65808.0        1         1
# 188   10949        1963       PhD       Divorced  72968.0        0         0
# 193     760        1975       PhD       Divorced  60554.0        1         0
# 225   10095        1975       PhD       Divorced  74165.0        0         0
# 248    2793        1976       PhD       Divorced  70179.0        0         1
# 249    1071        1976       PhD       Divorced  70179.0        0         1
# 783    3924        1965       PhD       Divorced  57912.0        0         1
# 816    2426        1964       PhD       Divorced  78825.0        0         0
# 859    2131        1959       PhD       Divorced  62859.0        0         1
# 940    9750        1961       PhD       Divorced  64325.0        0         1
# 1031   1184        1968       PhD       Divorced  69674.0        0         2
# ...

# %% [markdown]
# # MY 4th Graph
# Here,I will present the visualization of given datasets by three colomns.1.birth year,2.education,3.income

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

figure5 = make_subplots(rows=1,cols=2)

figure5.add_trace(go.scatter(df,x="Year_Birth",y="Education",row=1,col=1))

figure5.add_trace(go.scatter(df,x="Year_Birth",y="Marital_Status",row=1,col=2))

figure5.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 6
#       2 import plotly.graph_objects as go
#       4 figure5 = make_subplots(rows=1,cols=2)
# ----> 6 figure5.add_trace(go.scatter(df,x="Year_Birth",y="Education",row=1,col=1))
#       8 figure5.add_trace(go.scatter(df,x="Year_Birth",y="Marital_Status",row=1,col=2))
#      10 figure5.show()
#
# TypeError: 'module' object is not callable
